# %% [markdown]
# <a href="https://colab.research.google.com/github/nitvishnoi/LaneDetection/blob/main/lanedetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Upgrad/Project_LaneDetection
# Out:
# /content/drive/MyDrive/Upgrad/Project_LaneDetection

# %%
# !ls
# Out:
# DataSet  LaneDetection	LaneDetection.ipynb

# %%
#!git clone https://github.com/nitvishnoi/LaneDetection

# %%
# !ls
# Out:
# DataSet  LaneDetection	LaneDetection.ipynb

# %%
cd DataSet
# Out:
# /content/drive/MyDrive/Upgrad/Project_LaneDetection/DataSet

# %%
# !ls
# Out:
# CULane	CULane.zip  test_label_new.json  TUSimple  TuSimple.zip

# %%
#!unzip CULane.zip -d CULane/

# %%
# !ls
# Out:
# CULane	CULane.zip  test_label_new.json  TUSimple  TuSimple.zip

# %%
#!apt-get install p7zip-full

# %%
#!7za x TuSimple.zip

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Upgrad/Project_LaneDetection/DataSet

# %%
cd ../LaneDetection/
# Out:
# /content/drive/MyDrive/Upgrad/Project_LaneDetection/LaneDetection

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Upgrad/Project_LaneDetection/LaneDetection

# %%
#!ln -s $LANEDET_ROOT /content/drive/MyDrive/Upgrad/Project_LaneDetection/LaneDetection
os.environ['$LANEDET_ROOT'] = '/content/drive/MyDrive/Upgrad/Project_LaneDetection/LaneDetection'
print(os.getenv('$LANEDET_ROOT'))
# Out:
# /content/drive/MyDrive/Upgrad/Project_LaneDetection/LaneDetection

# %%
# !echo $LANEDET_ROOT

# %%
#os.environ['$CULANEROOT'] = '/content/drive/MyDrive/Upgrad/Project_LaneDetection/DataSet/CULane'
#print(os.getenv('$CULANEROOT'))

CULANEROOT = "/content/drive/MyDrive/Upgrad/Project_LaneDetection/DataSet/CULane"
# %cd {CULANEROOT}
# !pwd
# Out:
# /content/drive/MyDrive/Upgrad/Project_LaneDetection/DataSet/CULane
# /content/drive/MyDrive/Upgrad/Project_LaneDetection/DataSet/CULane

# %%
# !echo $CULANEROOT

# %%
TUSIMPLEROOT = "/content/drive/MyDrive/Upgrad/Project_LaneDetection/DataSet/TUSimple"
# %cd {TUSIMPLEROOT}
# !pwd
# Out:
# /content/drive/MyDrive/Upgrad/Project_LaneDetection/DataSet/TUSimple
# /content/drive/MyDrive/Upgrad/Project_LaneDetection/DataSet/TUSimple

# %%
# !echo $CULANEROOT
# !echo $TUSIMPLEROOT
# Out:
# /content/drive/MyDrive/Upgrad/Project_LaneDetection/DataSet/CULane
# /content/drive/MyDrive/Upgrad/Project_LaneDetection/DataSet/TUSimple
